# %%
# coding:utf-8
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
trade = pd.read_csv('../datas/t_trade.csv')
trade_test = pd.read_csv('../datas/t_trade_test.csv')
trade = pd.concat([trade,trade_test])
print trade.shape
trade.head()
# Out:
# (150594, 4)
#        id  is_risk  rowkey                   time
# 0   27863      0.0       3  2015-01-01 00:00:41.0
# 1  115201      0.0       6  2015-01-01 00:00:46.0
# 2  143711      0.0      13  2015-01-01 00:01:02.0
# 3  172699      0.0      32  2015-01-01 00:03:00.0
# 4   53265      0.0      43  2015-01-01 00:03:52.0

# %%
# ndata trade
p0 = trade[(trade['id']==27122)].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
#       id  is_risk  rowkey                   time
# 0  27122      0.0  948842  2015-06-30 16:42:59.0

# %%
# ndata trade
p0 = trade[(trade['id']==108996)].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
#        id  is_risk  rowkey                   time
# 0  108996      0.0  886211  2015-06-18 20:04:25.0
# 1  108996      0.0  597005  2015-05-01 19:57:31.0
# 2  108996      0.0  116269  2015-01-19 19:21:53.0
# 3  108996      0.0  101648  2015-01-17 14:43:48.0

# %%
# ndata trade
p0 = trade[(trade['id']==98451)&(trade['is_risk']==1)&(trade['time']<="2015-05-10 19:06:27")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
# Empty DataFrame
# Columns: [id, is_risk, rowkey, time]
# Index: []

# %%
# ndata trade
p0 = trade[(trade['id']==94357)&(trade['is_risk']==1)&(trade['time']<="2015-05-07 21:10:17")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
# Empty DataFrame
# Columns: [id, is_risk, rowkey, time]
# Index: []

# %%
# ndata trade
p0 = trade[(trade['id']==55341)&(trade['is_risk']==1)&(trade['time']<="2015-05-24 22:27:16")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
# Empty DataFrame
# Columns: [id, is_risk, rowkey, time]
# Index: []

# %%
# ndata trade
p0 = trade[(trade['id']==34477)&(trade['is_risk']==1)&(trade['time']<="2015-05-12 23:51:20")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
# Empty DataFrame
# Columns: [id, is_risk, rowkey, time]
# Index: []

# %%
# ndata trade
p0 = trade[(trade['id']==108996)&(trade['is_risk']==1)&(trade['time']<="2015-05-19 20:04:25")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
# Empty DataFrame
# Columns: [id, is_risk, rowkey, time]
# Index: []

# %% [markdown]
# ## lgb_30/lgb60_more

# %%
# ndata trade
p0 = trade[(trade['id']==148199)&(trade['time']>="2015-05-09 14:13:08")&(trade['time']<"2015-06-09 14:13:08")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
#        id  is_risk  rowkey                   time
# 0  148199      0.0  789051  2015-06-08 14:28:07.0
# 1  148199      0.0  789032  2015-06-08 14:24:03.0
# 2  148199      0.0  788958  2015-06-08 14:13:08.0
# 3  148199      0.0  788943  2015-06-08 14:11:04.0
# 4  148199      0.0  788936  2015-06-08 14:08:41.0
# 5  148199      0.0  788932  2015-06-08 14:08:06.0

# %%
# ndata trade
p0 = trade[(trade['id']==148199)&(trade['time']>="2015-05-09 14:11:04")&(trade['time']<"2015-06-09 14:11:04")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
#        id  is_risk  rowkey                   time
# 0  148199      0.0  789051  2015-06-08 14:28:07.0
# 1  148199      0.0  789032  2015-06-08 14:24:03.0
# 2  148199      0.0  788958  2015-06-08 14:13:08.0
# 3  148199      0.0  788943  2015-06-08 14:11:04.0
# 4  148199      0.0  788936  2015-06-08 14:08:41.0
# 5  148199      0.0  788932  2015-06-08 14:08:06.0

# %%
# ndata trade
p0 = trade[(trade['id']==175798)&(trade['time']>="2015-05-17 04:24:21")&(trade['time']<"2015-06-17 04:24:21")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
#        id  is_risk  rowkey                   time
# 0  175798      0.0  847994  2015-06-16 04:24:21.0

# %%
# ndata trade
p0 = trade[(trade['id']==66294)&(trade['time']>="2015-05-08 13:31:27")&(trade['time']<"2015-06-08 13:31:27")].sort_values('time',ascending=False).reset_index(drop=True)
# 30 min 以内多次交易，2 min，1min，5min，10min，1h，1day
p0.head(50)
# Out:
#        id  is_risk  rowkey                   time
# 