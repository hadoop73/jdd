# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\Administrator\\PycharmProjects\\JDD\\codes'

# %%
t_login = pd.read_csv('../datas/t_login.csv')
t_login.head()
# Out:
#          log_id  timelong  device  log_from       ip  city  result  \
# 0  2.618369e+15       5.0  879361        10  1026491   194       1
# 1  9.969739e+14   16124.0  835072         1  1026491   194       1
# 2  8.123343e+15       5.0  879361        10  1026491   194       1
# 3  3.265677e+14       6.0  879361        10  1026491   194       1
# 4  6.684659e+15       4.0  879361        10  1026491   194       1
#
#       timestamp  type      id  is_scan  is_sec                 time
# 0  1.428642e+09     1  116825     True   False  2015-04-10 12:54:19
# 1  1.428809e+09     1  109987    False   False  2015-04-12 11:20:45
# 2  1.427705e+09     1  116825     True   False  2015-03-30 16:38:20
# 3  1.428309e+09     1  116825     True   False  2015-04-06 16:22:18
# 4  1.428221e+09     1  116825     True   False  2015-04-05 15:55:01

# %%
sort_login = t_login.sort_values('time').reset_index(drop=True)
sort_login.head()
# Out:
#          log_id  timelong  device  log_from       ip  city  result  \
# 0  7.775528e+15       0.0  421584         2  1327200   364       1
# 1  5.707914e+14    3000.0  764868         1  1482812   102       1
# 2  2.350545e+16    2000.0  210427         2  1182527   103       1
# 3  2.161775e+16   12911.0   44973         1  1470338   485       1
# 4  7.393815e+15   12594.0  529364         1   869735    23       1
#
#       timestamp  type      id  is_scan  is_sec                 time
# 0  1.420042e+09     1  113124    False   False  2015-01-01 00:00:15
# 1  1.420042e+09     3  121137    False   False  2015-01-01 00:00:29
# 2  1.420042e+09     3    9219    False   False  2015-01-01 00:00:54
# 3  1.420042e+09     3  100340    False   False  2015-01-01 00:00:55
# 4  1.420042e+09     1   59555    False   False  2015-01-01 00:00:58

# %%
sort_login['timestamp_online'] = sort_login['timestamp'] + sort_login['timelong']
sort_login['result'] = sort_login['result'].map(lambda x: x == 1 and 1 or -1)
sort_login.head()
# Out:
#          log_id  timelong  device  log_from       ip  city  result  \
# 0  7.775528e+15       0.0  421584         2  1327200   364       1
# 1  5.707914e+14    3000.0  764868         1  1482812   102       1
# 2  2.350545e+16    2000.0  210427         2  1182527   103       1
# 3  2.161775e+16   12911.0   44973         1  1470338   485       1
# 4  7.393815e+15   12594.0  529364         1   869735    23       1
#
#       timestamp  type      id  is_scan  is_sec                 time  \
# 0  1.420042e+09     1  113124    False   False  2015-01-01 00:00:15
# 1  1.420042e+09     3  121137    False   False  2015-01-01 00:00:29
# 2  1.420042e+09     3    9219    False   False  2015-01-01 00:00:54
# 3  1.420042e+09     3  100340    False   False  2015-01-01 00:00:55
# 4  1.420042e+09     1   59555    False   False  2015-01-01 00:00:58
#
#    timestamp_online
# 0      1.420042e+09
# 1      1.420045e+09
# 2      1.420044e+09
# 3      1.420055e+09
# 4      1.420054e+09

# %%
# sort_login.index.tolist()

# %%
t_trade['a'] = np.NaN
t_trade.head()
# Out:
#    rowkey                   time      id  is_risk   a
# 0       3  2015-01-01 00:00:41.0   27863        0 NaN
# 1       6  2015-01-01 00:00:46.0  115201        0 NaN
# 2      13  2015-01-01 00:01:02.0  143711        0 NaN
# 3      32  2015-01-01 00:03:00.0  172699        0 NaN
# 4      43  2015-01-01 00:03:52.0   53265        0 NaN

# %%
t = t_trade.sort_values('time')
t.head()
# Out:
#        rowkey                   time      id  is_risk   a
# 66541       2  2015-01-01 00:00:40.0  171909        0 NaN
# 0           3  2015-01-01 00:00:41.0   27863        0 NaN
# 1           6  2015-01-01 00:00:46.0  115201        0 NaN
# 2          13  2015-01-01 00:01:02.0  143711        0 NaN
# 66542      18  2015-01-01 00:01:17.0   62643        0 NaN

# %%
dtt = t[t['time']>='2015-05-10 00:00:00.0']
dtt.head()
# Out:
#        rowkey                   time      id  is_risk   a
# 90738  633047  2015-05-10 00:04:03.0  162969        0 NaN
# 90739  633050  2015-05-10 00:05:09.0   62643        0 NaN
# 90740  633068  2015-05-10 00:11:55.0   51374        0 NaN
# 90741  633073  2015-05-10 00:13:13.0   23253        0 NaN
# 90742  633078  2015-05-10 00:16:16.0    3199        0 NaN

# %%
t.tail()
# Out:
#         rowkey                   time      id  is_risk   a
# 66539   950704  2015-06-30 23:46:14.0  160506        0 NaN
# 132716  950714  2015-06-30 23:49:32.0   72429        0 NaN
# 132717  950720  2015-06-30 23:51:08.0  106040        0 NaN
# 132718  950727  2015-06-30 23:53:19.0   72429        0 NaN
# 66540   950744  2015-06-30 23:56:39.0  126546        0 NaN

# %%
dt = t[t['time']>='2015-06-10 00:00:00.0']
dt.head()
# Out:
#         rowkey                   time      id  is_risk   a
# 113220  801668  2015-06-10 00:00:01.0   77205        0 NaN
# 113221  801671  2015-06-10 00:00:10.0   14558        0 NaN
# 113222  801679  2015-06-10 00:00:20.0   92262        0 NaN
# 113223  801690  2015-06-10 00:00:53.0   28478        0 NaN
# 113224  801692  2015-06-10 00:01:48.0  117384        0 NaN

# %%
dt[dt['is_risk']==1].shape
# Out:
# (203, 5)

# %%
t = t.reset_index(drop=True)
t['rowkey'].plot(figsize=(16,4))
plt.show()

# %% [markdown]
# ##  t_trad 分析

# %%
t_trade = pd.read_csv('../datas/t_trade.csv')
t_trade.head()
# Out:
#    rowkey                   time      id  is_risk
# 0       3  2015-01-01 00:00:41.0   27863        0
# 1       6  2015-01-01 00:00:46.0  115201        0
# 2      13  2015-01-01 00:01:02.0  143711        0
# 3      32  2015-01-01 00:03:00.0  172699        0
# 4      43  2015-01-01 00:03:52.0   53265        0

# %%
t_trade[t_trade['is_risk']==1].head(50)
# Out:
#       rowkey                   time      id  is_risk
# 29       555  2015-01-01 03:02:01.0   18138        1
# 30       560  2015-01-01 03:03:24.0   18138        1
# 32       566  2015-01-01 03:06:38.0   18138        1
# 34       576  2015-01-01 03:18:17.0   18138        1
# 87      1348  2015-01-01 10:13:14.0   65489        1
# 90      1369  2015-01-01 10:16:46.0   65489        1
# 119     1888  2015-01-01 11:36:30.0   90970        1
# 208     3334  2015-01-01 16:24:44.0   55986        1
# 396     5766  2015-01-02 01:01:00.0  154625        1
# 401     5868  2015-01-02 03:05:19.0  131624        1
# 402     5873  2015-01-02 03:14:39.0  131624        1
# 403     5876  2015-01-02 03:20:07.0  131624        1
# 404     5881  2015-01-02 03:25:07.0  131624        1
# 405     5883  2015-01-02 03:26:18.0  131624        1
# 380021  5.383593e+15    1000.0  163076         2   888257   102      31
#
#            timestamp  type     id  is_scan  is_sec                 time
# 51617   1.420048e+09     3  18138    False   False  2015-01-01 01:41:13
# 501080  1.420051e+09     3  18138    False   False  2015-01-01 02:38:52
# 398441  1.420052e+09     3  18138    False   False  2015-01-01 02:59:24
# 380021  1.420100e+09     2  18138    False   False  2015-01-01 16:18:07

# %%
# 把 time 和 id 转化为 list 方便进行多进程处理
# t_trade[['time','id']].values.tolist()
#time:2015-01-01 03:02:01.0  id:18138
# 给定 id 和 交易时间，筛选登录信息  ( 当天 1 个小时内的最近登录信息，最近的登录信息，最近的 3 次登录信息，最近 3 次登录的 ip 信息，log_from)
# 最近 3 次的 timelong 信息，最近 3 次的 city 信息，最近 1 次的交易信息，device 信息，是否使用安全控件，是否扫描
id = 18138
t_login['time'] = t_login['time'].astype(pd.Timestamp)
#print(t_login.dtypes)
time = pd.Timestamp('2015-01-01 03:20:01.0')
d = t_login[t_login['id']==id]
d['time'] = d['time'].astype(pd.Timestamp)
d[d['time']<'2015-03-01 03:20:01.0'].sort_values('time')
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#               log_id  timelong  device  log_from       ip  city  result  \
# 51617   8.379107e+15    3000.0  835072         2   489783    44       1
# 501080  5.612790e+15   22900.0   38853         1  1209900   471       1
# 398441  5.175043e+15    9000.0  835072         2   724987   418       1
# 380021  5.383593e+15    1000.0  163076         2   888257   102      31
# 82414   9.392919e+15    6000.0  163076         2   888257   102      31
# 82416   5.661011e+15    1000.0  163076         2   888257   102      31
# 380022  6.249668e+15    6000.0  163076         2   888257   102      31
# 82415   5.994414e+14    3000.0  163076         2   888257   102       1
# 278070  3.677110e+16       0.0  520400         2     6302   288      31
# 278069  5.006854e+15       0.0  520400         2     6302   288       1
# 575377  8.486992e+15   10878.0  529739         1     6302   288       1
# 144413  4.313217e+16    4000.0  221206         2   883233   102      31
# 442031  5.378616e+15    3000.0  221206         2   883233   102      31
# 144412  6.106803e+15       0.0  221206         2   883233   102      31
# 144415  6.391459e+15    1000.0  221206         2   883233   102       1
# 278072  9.550304e+15   10638.0  529739         1     6302   288      31
# 278071  7.815967e+15   16231.0  529739         1     6302   288       1
# 225403  6.056956e+15    6000.0  835072         2   764734   297      31
# 27778   4.925645e+15    9259.0  529739         1   564529   288      31
# 27777   9.255693e+15   15610.0  529739         1   564529   288      31
# 27775   3.680492e+15   20936.0  529739         1   564529   288      31
# 27779   5.625928e+15   26313.0  529739         1   564529   288      31
# 325840  8.291453e+15   32007.0  529739         1   564529   288      31
# 325841  6.603303e+15   44053.0  529739         1   564529   288      31
# 325842  6.495567e+15   62153.0  529739         1   564529   288      31
# 27776   4.004818e+14   88282.0  529739         1   564529   288       1
# 442035  2.164903e+16    1000.0  303412         2  1131501   102      31
# 144425  9.328083e+15    1000.0  303412         2  1131501   102      31
# 144424  6.425113e+14    1000.0  303412         2  1131501   102      31
# 144423  3.694242e+16       0.0  303412         2  1131501   102       1
# 90244   8.348316e+15    1000.0  163076         2   757848   288      31
# 90245   4.152926e+15    1000.0  163076         2   757848   288       1
# 203834  6.112115e+13   14946.0  529739         1   520788   288      31
# 501701  1.423886e+09     1  18138    False   False  2015-02-14 11:56:58
# 501704  1.423886e+09     1  18138    False   False  2015-02-14 11:57:04
# 203835  1.423886e+09     1  18138    False   False  2015-02-14 11:57:19
# 501702  1.423886e+09     1  18138    False   False  2015-02-14 11:57:31
# 501703  1.423886e+09     3  18138    False   False  2015-02-14 11:57:49
# 203836  1.423886e+09     3  18138    False   False  2015-02-14 11:58:10
# 388043  1.424782e+09     1  18138    False   False  2015-02-24 20:45:21
# 90247   1.424782e+09     1  18138    False   False  2015-02-24 20:45:51
# 388044  1.424782e+09     1  18138    False   False  2015-02-24 20:47:25
# 388046  1.424782e+09     3  18138    False   False  2015-02-24 20:47:40
# 90248   1.424782e+09     3  18138    False   False  2015-02-24 20:47:52
# 388045  1.424782e+09     3  18138    False   False  2015-02-24 20:51:42
# 90246   1.424868e+09     3  18138    False   False  2015-02-25 20:42:44
# 493632  1.424868e+09     3  18138    False   False  2015-02-25 20:47:38

# %%
dt = d[d['time']<'2015-01-01 03:20:01.0'].sort_values('time',ascending=False)\
                .reset_index(drop=True)
dt.head()
# Out:
#          log_id  timelong  device  log_from       ip  city  result  \
# 0  5.175043e+15    9000.0  835072         2   724987   418       1
# 1  5.612790e+15   22900.0   38853         1  1209900   471       1
# 2  8.379107e+15    3000.0  835072         2   489783    44       1
#
#       timestamp  type     id  is_scan  is_sec                 time
# 0  1.420052e+09     3  18138    False   False  2015-01-01 02:59:24
# 1  1.420051e+09     3  18138    False   False  2015-01-01 02:38:52
# 2  1.420048e+09     3  18138    False   False  2015-01-01 01:41:13

# %%
dt.head()
# Out:
#          log_id  timelong  device  log_from       ip  city  result  \
# 0  5.175043e+15    9000.0  835072         2   724987   418       1
# 1  5.612790e+15   22900.0   38853         1  1209900   471       1
# 2  8.379107e+15    3000.0  835072         2   489783    44       1
#
#       timestamp  type     id  is_scan  is_sec                 time
# 0  1.420052e+09     3  18138    False   False  2015-01-01 02:59:24
# 1  1.420051e+09     3  18138    False   False  2015-01-01 02:38:52
# 2  1.420048e+09     3  18138    False   False  2015-01-01 01:41:13

# %%
at = pd.Timestamp(dt.loc[0]['time'])
bt = pd.Timestamp(dt.loc[1]['time'])

# %%
at
# Out:
# Timestamp('2015-01-01 02:59:24')

# %%
bt
# Out:
# Timestamp('2015-01-01 02:38:52')

# %%
(at - bt).total_seconds()
# Out:
# 1232.0

# %%
dt.loc[0:3]['ip'].unique().size
# Out:
# 3

# %%
a.size
# Out:
# 3

# %%
t_trade['time'] = t_trade['time'].astype(pd.Timestamp)

# %%
t_trade[t_trade['id']==id].sort_values('time')
# Out:
#        rowkey                   time     id  is_risk
# 29        555  2015-01-01 03:02:01.0  18138        1
# 66580     557  2015-01-01 03:02:31.0  18138        1
# 30        560  2015-01-01 03:03:24.0  18138        1
# 66581     561  2015-01-01 03:04:16.0  18138        1
# 66582     563  2015-01-01 03:05:14.0  18138        1
# 31        564  2015-01-01 03:05:36.0  18138        0
# 32        566  2015-01-01 03:06:38.0  18138        1
# 66584     571  2015-01-01 03:16:36.0  18138        1
# 66585     572  2015-01-01 03:16:51.0  18138        1
# 66586     573  2015-01-01 03:17:30.0  18138        1
# 66587     574  2015-01-01 03:17:31.0  18138        1
# 34        576  2015-01-01 03:18:17.0  18138        1
# 16850  226216  2015-02-14 12:04:41.0  18138        0
# 26418  360046  2015-03-10 08:16:21.0  18138        0

# %%
t_trade.dtypes
# Out:
# rowkey      int64
# time       object
# id          int64
# is_risk     int64
# dtype: object

# %%
time = '2015-01-01 03:02:31.0'
t = pd.Timestamp(time)

# %%
t = t.date()

# %%
t.weekday()
# Out:
# 3

# %%
t.hour
# Out:
# 3

# %%
t_trade = t_trade.sort_values('time')
t_trade.head()
# Out:
#        rowkey                   time      id  is_risk
# 66541       2  2015-01-01 00:00:40.0  171909        0
# 0           3  2015-01-01 00:00:41.0   27863        0
# 1           6  2015-01-01 00:00:46.0  115201        0
# 2          13  2015-01-01 00:01:02.0  143711        0
# 66542      18  2015-01-01 00:01:17.0   62643        0

# %%
t_trade['time'] = t_trade['time'].map(lambda x:x[:11])
t_trade.head()
# Out:
#        rowkey         time      id  is_risk
# 66541       2  2015-01-01   171909        0
# 0           3  2015-01-01    27863        0
# 1           6  2015-01-01   115201        0
# 2          13  2015-01-01   143711        0
# 66542      18  2015-01-01    62643        0

# %%
dt = t_trade[['time','is_risk']].groupby('time',as_index=False).sum()
dt.head()
# Out:
#           time  is_risk
# 0  2015-01-01        21
# 1  2015-01-02        41
# 2  2015-01-03         4
# 3  2015-01-04         3
# 4  2015-01-05        32

# %%
da = dt.set_index('time',drop=True)
da.head()
# Out:
#              is_risk
# time
# 2015-01-01        21
# 2015-01-02        41
# 2015-01-03         4
# 2015-01-04         3
# 2015-01-05        32

# %%
da
# Out:
#              is_risk
# time
# 2015-01-01        21
# 2015-01-02        41
# 2015-01-03         4
# 2015-01-04         3
# 2015-01-05        32
# 2015-01-06        13
# 2015-01-07        23
# 2015-01-08        18
# 2015-01-09        10
# 2015-01-10        21
# 2015-01-11        23
# 2015-01-12        10
# 2015-01-13        19
# 2015-01-14         9
# 2015-01-15        12
# 2015-01-16        14
# 2015-01-17         4
# 2015-01-18        17
# 2015-01-19         7
# 2015-01-20        10
# 2015-01-21        14
# 2015-01-22        42
# 2015-01-23        21
# 2015-01-24        17
# 2015-01-25        19
# 2015-01-26        65
# 2015-01-27        16
# 2015-01-28        19
# 2015-01-29        26
# 2015-01-30        27
# ...              ...
# 2015-06-01        12
# 2015-06-02         7
# 2015-06-03        25
# 2015-06-04        10
# 2015-06-05        22
# 2015-06-06        15
# 2015-06-07        19
# 2015-06-08         0
# 2015-06-09         8
# 2015-06-10        10
# 2015-06-11         6
# 2015-06-12         0
# 2015-06-13        12
# 2015-06-14         1
# 2015-06-15         5
# 2015-06-16        13
# 2015-06-17         2
# 2015-06-18         8
# 2015-06-19         3
# 2015-06-20         7
# 2015-06-21        15
# 2015-06-22         3
# 2015-06-23        15
# 2015-06-24         9
# 2015-06-25         7
# 2015-06-26        17
# 2015-06-27        11
# 2015-06-28        15
# 2015-06-29        19
# 2015-06-30        25
#
# [181 rows x 1 columns]

# %%
da[:50].plot.bar( figsize=(16, 8))
plt.show()

# %%
da.is_risk.hist()
plt.show()
