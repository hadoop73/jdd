# %%
# coding:utf-8

import pandas as pd
import numpy as np

# %%
login = pd.read_csv('../datas/t_login.csv')

# %%
t5[t5['timelong']<10].sort_values('id').reset_index(drop=True)
# Out:
#              log_id  timelong   device  log_from       ip  city  result  \
# 0      3.347741e+16       4.0   103902        10   713606   253       1
# 1      3.662388e+15       3.0   717853        10   713606   253       1
# 2      9.117278e+15       5.0   993847        10   713606   253       1
# 3      5.887254e+16       4.0   183218        10   713606   253       1
# 4      6.629442e+15       4.0   615629        10   713606   253       1
# 5      7.719252e+15       5.0  1073053        10   713606   253       1
# 6      3.838801e+15       4.0   449213        10   713606   253       1
# 7      1.749926e+16       4.0    87061        10   713606   253       1
# 8      5.178582e+14       4.0  1073053        10   713606   253       1
# 9      1.758903e+15       6.0   957784        10   713606   253      -4
# 10     2.211287e+15       5.0   183218        10   713606   253       1
# 11     7.226174e+15       8.0    43002        10    86367    90       1
# ...

# %%
t5 = login[(login['time']<'2015-07-01 13:00:29.0')]
#t5 = t5[(t5['time']>'2015-06-01 00:43:43.0')]
#t5 = t5[(t5['time']<'2015-06-23 00:43:43.0')]

t5[t5['id']==80306].sort_values('time').reset_index(drop=True)
# Out:
#           log_id  timelong  device  log_from       ip  city  result  \
# 0   6.733529e+15   22678.0  362369         1   167389   276       1
# 1   3.220941e+15    8379.0  714919         1  1321812   459       1
# 2   8.485480e+15   11405.0  952411         1   981632   238       1
# 3   1.369983e+16   35492.0  845402         1   981632   238       1
# 4   6.885333e+15  291494.0  292549         1  1367983   238       1
# 5   3.395930e+16    6000.0   25749         2  1163773   238       1
# 6   8.842807e+15       6.0  832684        10   526422   396       1
# 7   4.657856e+15       6.0  832684        10   526422   396       1
# 8   8.939057e+15       6.0  832684        10   526422   396       1
# 9   5.844192e+15       4.0  832684        10   526422   396       1
# 10  2.330226e+15       5.0  832684        10   526422   396       1
# 11  4.329873e+15       5.0  832684        10   526422   396       1
# 12  9.814128e+15       5.0  832684        10   526422   396       1
# ...

# %%
t5[t5['ip']==175103].sort_values('time').reset_index(drop=True)
# Out:
#          log_id  timelong  device  log_from      ip  city  result  \
# 0  4.264209e+15    8598.0  234055         1  175103   430       1
#
#       timestamp  type      id  is_scan  is_sec                 time
# 0  1.435238e+09     1  111962    False   False  2015-06-25 21:19:53

# %%
t5[t5['device']==41327].sort_values('time').reset_index(drop=True)
# Out:
#          log_id  timelong  device  log_from      ip  city  result  \
# 0  1.526866e+15   17500.0   41327         1  837294   430       1
# 1  7.675945e+15   10379.0   41327         1  309044   430       1
# 2  1.873524e+15    9963.0   41327         1  616323    58       1
# 3  3.059566e+16    8145.0   41327         1  616323    58      31
#
#       timestamp  type      id  is_scan  is_sec                 time
# 0  1.435299e+09     1  101566    False   False  2015-06-26 14:06:17
# 1  1.435383e+09     1  101566    False   False  2015-06-27 13:36:34
# 2  1.435647e+09     3  137854    False   False  2015-06-30 14:44:35
# 3  1.435657e+09     3  137854    False   False  2015-06-30 17:32:41

# %%
t5[t5['device']==88].index
# Out:
# Int64Index([], dtype='int64')
